# %%
print("Welcome to Flight Delay Project ");
# Out:
# Welcome to Flight Delay Project

# %%
## this notebook make sure that the environment is working well

# %%
##Students : 
##Amro Muzahem 1220629
